# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiruthika2006-devil/preprocess-travelling-dataset/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# # Dataset is imported from github

# %%
df = pd.read_csv('https://github.com/Kiruthika2006-devil/preprocess-travelling-dataset/raw/main/travel_dataset.csv')
df.head()
# Out:
#    Trip ID   Location       Country    Category        Visitor Name  Age  \
# 0        1  Singapore     Singapore       urban  Jennifer Zimmerman   56
# 1        2  Cape Town  South Africa      nature       Megan Shaffer   18
# 2        3  Edinburgh            UK  historical       Melissa Singh   65
# 3        4      Dubai           UAE       urban     Rachel Reynolds   56
# 4        5  Cape Town  South Africa      nature     Danielle Wright   38
#
#    Gender  Rating Accommodation Available Accommodation Type  \
# 0    Male     4.4                     Yes              Hotel
# 1  Female     2.5                     Yes             Resort
# 2    Male     2.1                     Yes              Hotel
# 3    Male     3.5                     Yes             Resort
# 4  Female     1.1                     Yes          Apartment
#
#    Accommodation Amount Travel Start Date Travel End Date Transport Mode  \
# 0                   203        11/01/2024      11/08/2024         Cruise
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Trip ID                  1500 non-null   int64
#  1   Location                 1500 non-null   object
#  2   Country                  1500 non-null   object
#  3   Category                 1500 non-null   object
#  4   Visitor Name             1500 non-null   object
#  5   Age                      1500 non-null   int64
#  6   Gender                   1500 non-null   object
#  7   Rating                   1500 non-null   float64
#  8   Accommodation Available  1500 non-null   object
#  9   Accommodation Type       1500 non-null   object
#  10  Accommodation Amount     1500 non-null   int64
#  11  Travel Start Date        1500 non-null   object
#  12  Travel End Date          1500 non-null   object
#  13  Transport Mode           1500 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
